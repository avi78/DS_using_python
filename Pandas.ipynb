# %% [markdown]
# <a href="https://colab.research.google.com/github/avi78/DS_using_python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
a = pd.read_csv('a1.csv')
a
# Out:
#         day  temp  windspeed         event
# 0  22-02-24    24         21         strom
# 1  25-03-24    26         19        cloudy
# 2         3    28         15      moderate
# 3         4    21         11         rainy
# 4  11-03-24    23         10         sunny
# 5         6    27         16          cold
# 6         7    26         14          cold
# 7         8    22         13      moderate
# 8         9    25         10  light shower
# 9        10    29         11  light shower

# %%
a.head(1)
# Out:
#         day  temp  windspeed  event
# 0  22-02-24    24         21  strom

# %%
a.tail(2)
# Out:
#   day  temp  windspeed         event
# 8   9    25         10  light shower
# 9  10    29         11  light shower

# %%
a.columns
# Out:
# Index(['day', 'temp', 'windspeed', 'event'], dtype='object')

# %%
a.day
# Out:
# 0    22-02-24
# 1    25-03-24
# 2           3
# 3           4
# 4    11-03-24
# 5           6
# 6           7
# 7           8
# 8           9
# 9          10
# Name: day, dtype: object

# %%
a['event']
# Out:
# 0           strom
# 1          cloudy
# 2        moderate
# 3           rainy
# 4           sunny
# 5            cold
# 6            cold
# 7        moderate
# 8    light shower
# 9    light shower
# Name: event, dtype: object

# %%
type(a['event'])
# Out:
# pandas.core.series.Series

# %%
a[['event','day']]
# Out:
#           event       day
# 0         strom  22-02-24
# 1        cloudy  25-03-24
# 2      moderate         3
# 3         rainy         4
# 4         sunny  11-03-24
# 5          cold         6
# 6          cold         7
# 7      moderate         8
# 8  light shower         9
# 9  light shower        10

# %%
a['temp'].max()
# Out:
# 29

# %%
a['temp'].std()
# Out:
# 2.6012817353502227

# %%
a.describe()
# Out:
#             temp  windspeed
# count  10.000000  10.000000
# mean   25.100000  14.000000
# std     2.601282   3.800585
# min    21.000000  10.000000
# 25%    23.250000  11.000000
# 50%    25.500000  13.500000
# 75%    26.750000  15.750000
# max    29.000000  21.000000

# %%
a[a.temp>=25]
# Out:
#         day  temp  windspeed         event
# 1  25-03-24    26         19        cloudy
# 2         3    28         15      moderate
# 5         6    27         16          cold
# 6         7    26         14          cold
# 8         9    25         10  light shower
# 9        10    29         11  light shower

# %%
a[a.temp==a.temp.max()]
# Out:
#   day  temp  windspeed         event
# 9  10    29         11  light shower

# %%
a.set_index('day')
# Out:
#           temp  windspeed         event
# day
# 22-02-24    24         21         strom
# 25-03-24    26         19        cloudy
# 3           28         15      moderate
# 4           21         11         rainy
# 11-03-24    23         10         sunny
# 6           27         16          cold
# 7           26         14          cold
# 8           22         13      moderate
# 9           25         10  light shower
# 10          29         11  light shower

# %%
a.loc[4]
# Out:
# day          11-03-24
# temp               23
# windspeed          10
# event           sunny
# Name: 4, dtype: object

# %%
a.loc[a['day']=='22-02-24']
# Out:
#         day  temp  windspeed  event
# 0  22-02-24    24         21  strom

# %%
a[['day','temp']][a.temp==a['temp'].max()]
# Out:
#   day  temp
# 9  10    29

# %%
a.iloc[4]
# Out:
# day          11-03-24
# temp               23
# windspeed          10
# event           sunny
# Name: 4, dtype: object
